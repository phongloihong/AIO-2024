# %%
import torch.nn as nn
import torch.utils as TorchUtils
import torch.optim as optim
import numpy as np
import yaml
from datetime import datetime
from torchmetrics.classification import Accuracy
import torch
import pandas as pd
from torch.utils.data import Dataset

# %%
def label_dict_from_config_file(relative_path):
    with open(relative_path, 'r') as file:
        label_tag = yaml.full_load(file)['gestures']
    return label_tag

class CustomImageDataset(Dataset):
    def __init__(self, data_file):
        self.data = pd.read_csv(data_file)
        self.labels = torch.from_numpy(self.data.iloc[:,0].to_numpy())

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        one_hot_label = self.labels[idx]
        torch_data = torch.from_numpy(self.data.iloc[idx,1:].to_numpy(dtype=np.float32))
        return torch_data, one_hot_label

class EarlyStopper:
    def __init__(self, patience=1, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.watched_metrics = np.inf

    def early_stop(self, current_value):
        if current_value < self.watched_metrics:
            self.watched_metrics = current_value
            self.counter = 0
        elif current_value > (self.watched_metrics + self.min_delta):
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        list_label = label_dict_from_config_file('./data/hand_gesture.yaml')
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(63, 128),
            nn.ReLU(),
            nn.BatchNorm1d(128),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.4),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Dropout(0.6),
            nn.Linear(128, len(list_label))
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits
    
    def predict(self, x, threshold=0.8):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob, dim=1)
        return torch.where(softmax_prob[0, chosen_ind] > threshold, chosen_ind, -1)
    
    def predict_with_know_class(self, x):
        logits = self(x)
        softmax_prob = nn.Softmax(dim=1)(logits)
        chosen_ind = torch.argmax(softmax_prob, dim=1)
        return chosen_ind
    
    def score(self, logits):
        return torch.amax(logits, dim=1)

# %%
def train(train_loader, val_loader, model: NeuralNetwork, optimizer, loss_function, early_stopper):
    best_vloss = 1_000_000
    timestamp = datetime.now().strftime("%d-%m %H:%M")
    list_label = label_dict_from_config_file('./data/hand_gesture.yaml')
    for epoch in range(300):
        model.train(True)
        running_loss = 0.0
        acc_train = Accuracy(num_classes=len(list_label), task='multiclass')
        for batch_number,data in enumerate(train_loader):
            inputs, labels = data
            optimizer.zero_grad()
            outputs = model(inputs)

            loss = loss_function(outputs, labels)
            loss.backward()
            optimizer.step()

            acc_train.update(model.predict_with_know_class(inputs), labels)
            running_loss += loss.item()
    
        avg_loss = running_loss / len(train_loader)

        # validation step
        model.train(False)
        running_v_loss = 0.0
        acc_val = Accuracy(num_classes=len(list_label), task='multiclass')
        for i, v_data in enumerate(train_loader):
            v_inputs, v_labels = v_data
            outputs = model(v_inputs)
            v_loss = loss_function(outputs, v_labels)
            running_v_loss += v_loss.item()
            acc_val.update(model.predict_with_know_class(v_inputs), v_labels)

        # log the running loss averaged per batch
        # for both training and validation
        print(f"Epoch {epoch}: ")
        print(f"Accuracy train:{acc_train.compute().item()}, val:{acc_val.compute().item()}")
        avg_vloss = running_v_loss / len(val_loader)
        print('LOSS train {} valid {}'.format(avg_loss, avg_vloss))
        print('Training vs. Validation Loss',
                        { 'Training' : avg_loss, 'Validation' : avg_vloss },
                        epoch + 1)
        print('Training vs. Validation accuracy',
                        { 'Training' : acc_train.compute().item()
                        , 'Validation' : acc_val.compute().item() },
                        epoch + 1)
            
        # Track best performance, and save the model's state
        if avg_vloss < best_vloss:
            best_vloss = avg_vloss
            best_model_path = f'./model/model_{timestamp}_{model.__class__.__name__}_best'
            torch.save(model.state_dict(), best_model_path)

        if early_stopper.early_stop(avg_vloss):
            print('Early stopping')
            break
        
    model_path = f'./model/model_{timestamp}_{model.__class__.__name__}_last'
    torch.save(model.state_dict(), model_path)

    print(acc_val.compute())
    return model, best_model_path

# %%
LIST_LABEL = label_dict_from_config_file("./data/hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"

train_set = CustomImageDataset("./data/landmark_train.csv")
train_loader = TorchUtils.data.DataLoader(train_set, batch_size=40, shuffle=True)

val_set = CustomImageDataset("./data/landmark_val.csv")
val_loader = TorchUtils.data.DataLoader(val_set, batch_size=50, shuffle=False)

model = NeuralNetwork()
loss_function = nn.CrossEntropyLoss()
early_stopper = EarlyStopper(patience=3, min_delta=0.0001)

# optimizer
lr = 0.0001
optimizer = optim.Adam(model.parameters(), lr=lr)

model, best_model_path = train(train_loader, val_loader, model, optimizer, loss_function, early_stopper)
# Out:
# Epoch 0:
# Accuracy train:0.16192345321178436, val:0.29440629482269287
# LOSS train 1.7973114985686083 valid 7.704931199550629
# Training vs. Validation Loss {'Training': 1.7973114985686083, 'Validation': 7.704931199550629} 1
# Training vs. Validation accuracy {'Training': 0.16192345321178436, 'Validation': 0.29440629482269287} 1
# Epoch 1:
# Accuracy train:0.23552502691745758, val:0.33856722712516785
# LOSS train 1.767214807180258 valid 7.576145907243093
# Training vs. Validation Loss {'Training': 1.767214807180258, 'Validation': 7.576145907243093} 2
# Training vs. Validation accuracy {'Training': 0.23552502691745758, 'Validation': 0.33856722712516785} 2
# Epoch 2:
# Accuracy train:0.2875367999076843, val:0.3356231451034546
# LOSS train 1.7417794878666217 valid 7.435703078905742
# Training vs. Validation Loss {'Training': 1.7417794878666217, 'Validation': 7.435703078905742} 3
# Training vs. Validation accuracy {'Training': 0.2875367999076843, 'Validation': 0.3356231451034546} 3
# Epoch 3:
# Accuracy train:0.3179587721824646, val:0.3915603458881378
# LOSS train 1.709639297081874 valid 7.269363025824229
# Training vs. Validation Loss {'Training': 1.709639297081874, 'Validation': 7.269363025824229} 4
# Training vs. Validation accuracy {'Training': 0.3179587721824646, 'Validation': 0.3915603458881378} 4
# Epoch 4:
# Accuracy train:0.36604514718055725, val:0.4219823479652405
# LOSS train 1.6680452869488642 valid 7.069116234779358
# Training vs. Validation Loss {'Training': 1.6680452869488642, 'Validation': 7.069116234779358} 5
# Training vs. Validation accuracy {'Training': 0.36604514718055725, 'Validation': 0.4219823479652405} 5
# Epoch 5:
# Accuracy train:0.35623160004615784, val:0.4720314145088196
# LOSS train 1.610038881118481 valid 6.737567702929179
# Training vs. Validation Loss {'Training': 1.610038881118481, 'Validation': 6.737567702929179} 6
# Training vs. Validation accuracy {'Training': 0.35623160004615784, 'Validation': 0.4720314145088196} 6
# Epoch 6:
# Accuracy train:0.4219823479652405, val:0.490677148103714
# LOSS train 1.5456011662116418 valid 6.30277556180954
# Training vs. Validation Loss {'Training': 1.5456011662116418, 'Validation': 6.30277556180954} 7
# Training vs. Validation accuracy {'Training': 0.4219823479652405, 'Validation': 0.490677148103714} 7
# Epoch 7:
# Accuracy train:0.4504415988922119, val:0.5436702370643616
# LOSS train 1.4303031517909124 valid 5.727325399716695
# Training vs. Validation Loss {'Training': 1.4303031517909124, 'Validation': 5.727325399716695} 8
# Training vs. Validation accuracy {'Training': 0.4504415988922119, 'Validation': 0.5436702370643616} 8
# Epoch 8:
# Accuracy train:0.500490665435791, val:0.5583905577659607
# LOSS train 1.321689995435568 valid 5.047642429669698
# Training vs. Validation Loss {'Training': 1.321689995435568, 'Validation': 5.047642429669698} 9
# Training vs. Validation accuracy {'Training': 0.500490665435791, 'Validation': 0.5583905577659607} 9
# Epoch 9:
# Accuracy train:0.5632973313331604, val:0.6005887985229492
# LOSS train 1.1979163999740894 valid 4.385352065165837
# Training vs. Validation Loss {'Training': 1.1979163999740894, 'Validation': 4.385352065165837} 10
# Training vs. Validation accuracy {'Training': 0.5632973313331604, 'Validation': 0.6005887985229492} 10
# Epoch 10:
# Accuracy train:0.5986260771751404, val:0.7046123743057251
# LOSS train 1.0576767806823437 valid 3.7814641892910004
# Training vs. Validation Loss {'Training': 1.0576767806823437, 'Validation': 3.7814641892910004} 11
# Training vs. Validation accuracy {'Training': 0.5986260771751404, 'Validation': 0.7046123743057251} 11
# Epoch 11:
# Accuracy train:0.6516192555427551, val:0.7684003710746765
# LOSS train 0.937320759663215 valid 3.249597986539205
# Training vs. Validation Loss {'Training': 0.937320759663215, 'Validation': 3.249597986539205} 12
# Training vs. Validation accuracy {'Training': 0.6516192555427551, 'Validation': 0.7684003710746765} 12
# Epoch 12:
# Accuracy train:0.7379783987998962, val:0.9077526926994324
# LOSS train 0.8347087525404416 valid 2.6453046997388205
# Training vs. Validation Loss {'Training': 0.8347087525404416, 'Validation': 2.6453046997388205} 13
# Training vs. Validation accuracy {'Training': 0.7379783987998962, 'Validation': 0.9077526926994324} 13
# Epoch 13:
# Accuracy train:0.8066732287406921, val:0.9067713618278503
# LOSS train 0.6833681143247164 valid 2.251390511790911
# Training vs. Validation Loss {'Training': 0.6833681143247164, 'Validation': 2.251390511790911} 14
# Training vs. Validation accuracy {'Training': 0.8066732287406921, 'Validation': 0.9067713618278503} 14
# Epoch 14:
# Accuracy train:0.8547595739364624, val:0.98233562707901
# LOSS train 0.5864458427979395 valid 1.6600829164187114
# Training vs. Validation Loss {'Training': 0.5864458427979395, 'Validation': 1.6600829164187114} 15
# Training vs. Validation accuracy {'Training': 0.8547595739364624, 'Validation': 0.98233562707901} 15
# Epoch 15:
# Accuracy train:0.91167813539505, val:0.9931305050849915
# LOSS train 0.4695641558903914 valid 1.2041428784529369
# Training vs. Validation Loss {'Training': 0.4695641558903914, 'Validation': 1.2041428784529369} 16
# Training vs. Validation accuracy {'Training': 0.91167813539505, 'Validation': 0.9931305050849915} 16
# Epoch 16:
# Accuracy train:0.92934250831604, val:0.9901864528656006
# LOSS train 0.3630676303918545 valid 0.7953724414110184
# Training vs. Validation Loss {'Training': 0.3630676303918545, 'Validation': 0.7953724414110184} 17
# Training vs. Validation accuracy {'Training': 0.92934250831604, 'Validation': 0.9901864528656006} 17
# Epoch 17:
# Accuracy train:0.9450441598892212, val:0.9872424006462097
# LOSS train 0.29672970278904987 valid 0.55276183411479
# Training vs. Validation Loss {'Training': 0.29672970278904987, 'Validation': 0.55276183411479} 18
# Training vs. Validation accuracy {'Training': 0.9450441598892212, 'Validation': 0.9872424006462097} 18
# Epoch 18:
# Accuracy train:0.9607458114624023, val:0.9882237315177917
# LOSS train 0.2280895420565055 valid 0.3927521252383788
# Training vs. Validation Loss {'Training': 0.2280895420565055, 'Validation': 0.3927521252383788} 19
# Training vs. Validation accuracy {'Training': 0.9607458114624023, 'Validation': 0.9882237315177917} 19
# Epoch 19:
# Accuracy train:0.9666339755058289, val:0.9882237315177917
# LOSS train 0.19064308817570025 valid 0.284909109895428
# Training vs. Validation Loss {'Training': 0.19064308817570025, 'Validation': 0.284909109895428} 20
# Training vs. Validation accuracy {'Training': 0.9666339755058289, 'Validation': 0.9882237315177917} 20
# Epoch 20:
# Accuracy train:0.9695780277252197, val:0.9872424006462097
# LOSS train 0.15291585171451935 valid 0.2405126721908649
# Training vs. Validation Loss {'Training': 0.15291585171451935, 'Validation': 0.2405126721908649} 21
# Training vs. Validation accuracy {'Training': 0.9695780277252197, 'Validation': 0.9872424006462097} 21
# Epoch 21:
# Accuracy train:0.9774288535118103, val:0.9862610697746277
# LOSS train 0.13307027934262386 valid 0.19990041805431247
# Training vs. Validation Loss {'Training': 0.13307027934262386, 'Validation': 0.19990041805431247} 22
# Training vs. Validation accuracy {'Training': 0.9774288535118103, 'Validation': 0.9862610697746277} 22
# Epoch 22:
# Accuracy train:0.9764475226402283, val:0.9901864528656006
# LOSS train 0.12111060020442192 valid 0.16475344837332764
# Training vs. Validation Loss {'Training': 0.12111060020442192, 'Validation': 0.16475344837332764} 23
# Training vs. Validation accuracy {'Training': 0.9764475226402283, 'Validation': 0.9901864528656006} 23
# Epoch 23:
# Accuracy train:0.98233562707901, val:0.9882237315177917
# LOSS train 0.11308856079211602 valid 0.15370733197778463
# Training vs. Validation Loss {'Training': 0.11308856079211602, 'Validation': 0.15370733197778463} 24
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9882237315177917} 24
# Epoch 24:
# Accuracy train:0.9842983484268188, val:0.9872424006462097
# LOSS train 0.09427717514336109 valid 0.15460536698810756
# Training vs. Validation Loss {'Training': 0.09427717514336109, 'Validation': 0.15460536698810756} 25
# Training vs. Validation accuracy {'Training': 0.9842983484268188, 'Validation': 0.9872424006462097} 25
# Epoch 25:
# Accuracy train:0.9754661321640015, val:0.9901864528656006
# LOSS train 0.08956580064617671 valid 0.12510931600506106
# Training vs. Validation Loss {'Training': 0.08956580064617671, 'Validation': 0.12510931600506106} 26
# Training vs. Validation accuracy {'Training': 0.9754661321640015, 'Validation': 0.9901864528656006} 26
# Epoch 26:
# Accuracy train:0.98233562707901, val:0.9872424006462097
# LOSS train 0.08236226700962736 valid 0.1309880130769064
# Training vs. Validation Loss {'Training': 0.08236226700962736, 'Validation': 0.1309880130769064} 27
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9872424006462097} 27
# Epoch 27:
# Accuracy train:0.983316957950592, val:0.9872424006462097
# LOSS train 0.08580673263909724 valid 0.14091472971873978
# Training vs. Validation Loss {'Training': 0.08580673263909724, 'Validation': 0.14091472971873978} 28
# Training vs. Validation accuracy {'Training': 0.983316957950592, 'Validation': 0.9872424006462097} 28
# Epoch 28:
# Accuracy train:0.9793915748596191, val:0.9911677837371826
# LOSS train 0.06424094836872357 valid 0.11243393473948042
# Training vs. Validation Loss {'Training': 0.06424094836872357, 'Validation': 0.11243393473948042} 29
# Training vs. Validation accuracy {'Training': 0.9793915748596191, 'Validation': 0.9911677837371826} 29
# Epoch 29:
# Accuracy train:0.9882237315177917, val:0.9911677837371826
# LOSS train 0.0721857835753606 valid 0.10948593685558687
# Training vs. Validation Loss {'Training': 0.0721857835753606, 'Validation': 0.10948593685558687} 30
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9911677837371826} 30
# Epoch 30:
# Accuracy train:0.9872424006462097, val:0.9921491742134094
# LOSS train 0.06004390557511495 valid 0.1034169337945059
# Training vs. Validation Loss {'Training': 0.06004390557511495, 'Validation': 0.1034169337945059} 31
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9921491742134094} 31
# Epoch 31:
# Accuracy train:0.9862610697746277, val:0.9911677837371826
# LOSS train 0.08167335369552557 valid 0.13621510770947984
# Training vs. Validation Loss {'Training': 0.08167335369552557, 'Validation': 0.13621510770947984} 32
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9911677837371826} 32
# Epoch 32:
# Accuracy train:0.9872424006462097, val:0.9901864528656006
# LOSS train 0.06807218635311493 valid 0.10320046540194501
# Training vs. Validation Loss {'Training': 0.06807218635311493, 'Validation': 0.10320046540194501} 33
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9901864528656006} 33
# Epoch 33:
# Accuracy train:0.9872424006462097, val:0.9901864528656006
# LOSS train 0.05652668552759748 valid 0.10801383721021314
# Training vs. Validation Loss {'Training': 0.05652668552759748, 'Validation': 0.10801383721021314} 34
# Training vs. Validation accuracy {'Training': 0.9872424006462097, 'Validation': 0.9901864528656006} 34
# Epoch 34:
# Accuracy train:0.9892051219940186, val:0.9931305050849915
# LOSS train 0.0692556445988325 valid 0.10322247982063952
# Training vs. Validation Loss {'Training': 0.0692556445988325, 'Validation': 0.10322247982063952} 35
# Training vs. Validation accuracy {'Training': 0.9892051219940186, 'Validation': 0.9931305050849915} 35
# Epoch 35:
# Accuracy train:0.9882237315177917, val:0.9921491742134094
# LOSS train 0.05591168619978886 valid 0.09231458383146673
# Training vs. Validation Loss {'Training': 0.05591168619978886, 'Validation': 0.09231458383146673} 36
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9921491742134094} 36
# Epoch 36:
# Accuracy train:0.9862610697746277, val:0.9931305050849915
# LOSS train 0.06369525853257912 valid 0.08712651922057073
# Training vs. Validation Loss {'Training': 0.06369525853257912, 'Validation': 0.08712651922057073} 37
# Training vs. Validation accuracy {'Training': 0.9862610697746277, 'Validation': 0.9931305050849915} 37
# Epoch 37:
# Accuracy train:0.9882237315177917, val:0.9892051219940186
# LOSS train 0.052791679063095495 valid 0.10323913308093324
# Training vs. Validation Loss {'Training': 0.052791679063095495, 'Validation': 0.10323913308093324} 38
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9892051219940186} 38
# Epoch 38:
# Accuracy train:0.9901864528656006, val:0.9941118955612183
# LOSS train 0.04929149512631389 valid 0.07974160593585111
# Training vs. Validation Loss {'Training': 0.04929149512631389, 'Validation': 0.07974160593585111} 39
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9941118955612183} 39
# Epoch 39:
# Accuracy train:0.98233562707901, val:0.9882237315177917
# LOSS train 0.052307215716259986 valid 0.11053563882402766
# Training vs. Validation Loss {'Training': 0.052307215716259986, 'Validation': 0.11053563882402766} 40
# Training vs. Validation accuracy {'Training': 0.98233562707901, 'Validation': 0.9882237315177917} 40
# Epoch 40:
# Accuracy train:0.9921491742134094, val:0.9931305050849915
# LOSS train 0.052113948443617955 valid 0.07730865115202808
# Training vs. Validation Loss {'Training': 0.052113948443617955, 'Validation': 0.07730865115202808} 41
# Training vs. Validation accuracy {'Training': 0.9921491742134094, 'Validation': 0.9931305050849915} 41
# Epoch 41:
# Accuracy train:0.9911677837371826, val:0.9941118955612183
# LOSS train 0.05027765426068352 valid 0.06945600628387183
# Training vs. Validation Loss {'Training': 0.05027765426068352, 'Validation': 0.06945600628387183} 42
# Training vs. Validation accuracy {'Training': 0.9911677837371826, 'Validation': 0.9941118955612183} 42
# Epoch 42:
# Accuracy train:0.9882237315177917, val:0.9921491742134094
# LOSS train 0.04542821982445625 valid 0.10183788247619911
# Training vs. Validation Loss {'Training': 0.04542821982445625, 'Validation': 0.10183788247619911} 43
# Training vs. Validation accuracy {'Training': 0.9882237315177917, 'Validation': 0.9921491742134094} 43
# Epoch 43:
# Accuracy train:0.9901864528656006, val:0.9892051219940186
# LOSS train 0.056291121452187114 valid 0.10272723652694064
# Training vs. Validation Loss {'Training': 0.056291121452187114, 'Validation': 0.10272723652694064} 44
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9892051219940186} 44
# Epoch 44:
# Accuracy train:0.9901864528656006, val:0.9931305050849915
# LOSS train 0.04277354462717015 valid 0.08440868624893483
# Training vs. Validation Loss {'Training': 0.04277354462717015, 'Validation': 0.08440868624893483} 45
# Training vs. Validation accuracy {'Training': 0.9901864528656006, 'Validation': 0.9931305050849915} 45
# Early stopping
# tensor(0.9931)

# %%
list_label = label_dict_from_config_file("./data/hand_gesture.yaml")
DATA_FOLDER_PATH="./data/"
testset = CustomImageDataset("./data/landmark_test.csv")

# Test DataLoader instantiation
################## Your Code Here ################## Q6
''' Hoàn thành code bên dưới để  khởi tạo DataLoader cho testset with batch size
20, không cho phép shuffle
'''
test_loader = TorchUtils.data.DataLoader(testset, batch_size=20, shuffle=False)
####################################################



network = NeuralNetwork()
network.load_state_dict(torch.load(best_model_path, weights_only=False))

network.eval()
acc_test = Accuracy(num_classes=len(list_label), task='MULTICLASS')
for i, test_data in enumerate(test_loader):
    test_input, test_label = test_data
    preds = network.predict(test_input)
    acc_test.update(preds, test_label)

    ####################################################

print(network.__class__.__name__)
print(f"Accuracy of model:{acc_test.compute().item()}")
print("========================================================================")
# Out:
# NeuralNetwork
# Accuracy of model:0.8070865869522095
# ========================================================================
